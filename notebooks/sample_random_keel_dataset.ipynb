# %% [markdown]
# ### Import stuff

# %%
import random
from src.read_data import DataReader
from src.classification import CommonClassification
from src.preprocessing import CommonPreprocessing

# %% [markdown]
# ### Setup parameters

# %%
DATA_DIR = "../data"
TRAIN_TEST_SPLIT_RATIO = 0.25

# %% [markdown]
# ### Create required objects

# %%
data_reader = DataReader(DATA_DIR)
common_classifier = CommonClassification()
common_preprocessing = CommonPreprocessing()

# %% [markdown]
# ### Load all KEEL datasets from directory

# %%
keel_data = data_reader.read_keel_dat_directory()
print('Read KEEL Datasets: %s' % len(keel_data))
# Out:
# Read KEEL Datasets: 20

# %% [markdown]
# ### Select random KEEL dataset

# %%
random_keel_data = random.choice(keel_data)
random_keel_data.print_info()
random_keel_data.plot_class_distribution()
# Out:
# Keel Dataset Info:
# ==> File Name: yeast6.dat
# ==> Size: 1471
# ==> Features: 8
# ==> Classes: 2
# ==> Imbalance Ratio: 41.02857142857143

# %% [markdown]
# ### Convert KEEL data to testable collections

# %%
random_testable_keel_data = random_keel_data.as_testable(test_size=TRAIN_TEST_SPLIT_RATIO)
random_testable_keel_data.print_info()
random_testable_keel_data.plot_train_class_distribution()
# Out:
# Keel Testable Dataset Info:
# ==> File Name: yeast6.dat
# ==> Size: 1471
# ==> Features: 8
# ==> Classes: 2
# ==> Test-Train Split Ratio: 0.25
# ==> Train Size: 1103
# ==> Train Imbalance Ratio: 39.851851851851855
# ==> Test Size: 368
# ==> Test Imbalance Ratio: 45.0

# %% [markdown]
# ### Sample data with Random Undersampling

# %%
sampled_testable_keel_data = common_preprocessing.random_under_sampling(random_testable_keel_data)
sampled_testable_keel_data.print_info()
sampled_testable_keel_data.plot_train_class_distribution()
# Out:
# Keel Testable Dataset Info:
# ==> File Name: yeast6.dat
# ==> Size: 70
# ==> Features: 8
# ==> Classes: 2
# ==> Test-Train Split Ratio: 0.2962962962962963
# ==> Train Size: 54
# ==> Train Imbalance Ratio: 1.0
# ==> Test Size: 16
# ==> Test Imbalance Ratio: 1.0

# %% [markdown]
# ### Sample data with Cluster Centroids Undersampling

# %%
sampled_testable_keel_data = common_preprocessing.cluster_centroids_under_sampling(random_testable_keel_data)
sampled_testable_keel_data.print_info()
sampled_testable_keel_data.plot_train_class_distribution()
# Out:
# Keel Testable Dataset Info:
# ==> File Name: yeast6.dat
# ==> Size: 70
# ==> Features: 8
# ==> Classes: 2
# ==> Test-Train Split Ratio: 0.2962962962962963
# ==> Train Size: 54
# ==> Train Imbalance Ratio: 1.0
# ==> Test Size: 16
# ==> Test Imbalance Ratio: 1.0

# %% [markdown]
# ### Sample data with Random Oversampling

# %%
sampled_testable_keel_data = common_preprocessing.random_over_sampling(random_testable_keel_data)
sampled_testable_keel_data.print_info()
sampled_testable_keel_data.plot_train_class_distribution()
# Out:
# Keel Testable Dataset Info:
# ==> File Name: yeast6.dat
# ==> Size: 2872
# ==> Features: 8
# ==> Classes: 2
# ==> Test-Train Split Ratio: 0.3345724907063197
# ==> Train Size: 2152
# ==> Train Imbalance Ratio: 1.0
# ==> Test Size: 720
# ==> Test Imbalance Ratio: 1.0

# %% [markdown]
# ### Sample data with SMOTE Oversampling

# %%
sampled_testable_keel_data = common_preprocessing.smote_over_sampling(random_testable_keel_data)
sampled_testable_keel_data.print_info()
sampled_testable_keel_data.plot_train_class_distribution()
# Out:
# Keel Testable Dataset Info:
# ==> File Name: yeast6.dat
# ==> Size: 2872
# ==> Features: 8
# ==> Classes: 2
# ==> Test-Train Split Ratio: 0.3345724907063197
# ==> Train Size: 2152
# ==> Train Imbalance Ratio: 1.0
# ==> Test Size: 720
# ==> Test Imbalance Ratio: 1.0

# %% [markdown]
# ### Sample data with ADASYN Oversampling

# %%
sampled_testable_keel_data = common_preprocessing.adasyn_over_sampling(random_testable_keel_data)
sampled_testable_keel_data.print_info()
sampled_testable_keel_data.plot_train_class_distribution()
# Out:
# Keel Testable Dataset Info:
# ==> File Name: yeast6.dat
# ==> Size: 2871
# ==> Features: 8
# ==> Classes: 2
# ==> Test-Train Split Ratio: 0.3341078066914498
# ==> Train Size: 2152
# ==> Train Imbalance Ratio: 1.0
# ==> Test Size: 719
# ==> Test Imbalance Ratio: 1.0027855153203342
