# %% [markdown]
# ### Import stuff

# %%
import random
from src.read_data import DataReader
from src.classification import CommonClassification
from src.preprocessing import CommonPreprocessing

# %% [markdown]
# ### Setup parameters

# %%
DATA_DIR = "../data"
TRAIN_TEST_SPLIT_RATIO = 0.25

# %% [markdown]
# ### Create required objects

# %%
data_reader = DataReader(DATA_DIR)
common_classifier = CommonClassification()
common_preprocessing = CommonPreprocessing()

# %% [markdown]
# ### Load all KEEL datasets from directory

# %%
keel_data = data_reader.read_keel_dat_directory()
print('Read KEEL Datasets: %s' % len(keel_data))
# Out:
# Read KEEL Datasets: 11

# %% [markdown]
# ### Select random KEEL dataset

# %%
random_keel_data = random.choice(keel_data)
random_keel_data.print_info()
random_keel_data.plot_class_distribution()
# Out:
# Keel Dataset Info:
# ==> File Name: ecoli-0-1-4-7_vs_2-3-5-6.dat
# ==> Size: 323
# ==> Features: 7
# ==> Classes: 2

# %% [markdown]
# ### Convert KEEL data to testable collections

# %%
random_testable_keel_data = random_keel_data.as_testable(test_size=TRAIN_TEST_SPLIT_RATIO)
random_testable_keel_data.print_info()
random_testable_keel_data.plot_train_class_distribution()
# Out:
# Keel Testable Dataset Info:
# ==> File Name: ecoli-0-1-4-7_vs_2-3-5-6.dat
# ==> Size: 323
# ==> Features: 7
# ==> Classes: 2
# ==> Test-Train Split Ratio: 0.25
# ==> Train Size: 242
# ==> Test Size: 81

# %% [markdown]
# ### Sample data with Random Undersampling

# %%
sampled_testable_keel_data = common_preprocessing.random_under_sampling(random_testable_keel_data)
sampled_testable_keel_data.print_info()
sampled_testable_keel_data.plot_train_class_distribution()
# Out:
# Keel Testable Dataset Info:
# ==> File Name: ecoli-0-1-4-7_vs_2-3-5-6.dat
# ==> Size: 58
# ==> Features: 7
# ==> Classes: 2
# ==> Test-Train Split Ratio: 0.11538461538461539
# ==> Train Size: 52
# ==> Test Size: 6

# %% [markdown]
# ### Sample data with Cluster Centroids Undersampling

# %%
sampled_testable_keel_data = common_preprocessing.cluster_centroids_under_sampling(random_testable_keel_data)
sampled_testable_keel_data.print_info()
sampled_testable_keel_data.plot_train_class_distribution()
# Out:
# Keel Testable Dataset Info:
# ==> File Name: ecoli-0-1-4-7_vs_2-3-5-6.dat
# ==> Size: 58
# ==> Features: 7
# ==> Classes: 2
# ==> Test-Train Split Ratio: 0.11538461538461539
# ==> Train Size: 52
# ==> Test Size: 6

# %% [markdown]
# ### Sample data with Random Oversampling

# %%
sampled_testable_keel_data = common_preprocessing.random_over_sampling(random_testable_keel_data)
sampled_testable_keel_data.print_info()
sampled_testable_keel_data.plot_train_class_distribution()
# Out:
# Keel Testable Dataset Info:
# ==> File Name: ecoli-0-1-4-7_vs_2-3-5-6.dat
# ==> Size: 588
# ==> Features: 7
# ==> Classes: 2
# ==> Test-Train Split Ratio: 0.3611111111111111
# ==> Train Size: 432
# ==> Test Size: 156

# %% [markdown]
# ### Sample data with SMOTE Oversampling

# %%
sampled_testable_keel_data = common_preprocessing.smote_over_sampling(random_testable_keel_data)
sampled_testable_keel_data.print_info()
sampled_testable_keel_data.plot_train_class_distribution()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-0f3fcdae1817> in <module>
# ----> 1 sampled_testable_keel_data = common_preprocessing.smote_over_sampling(random_testable_keel_data)
#       2 sampled_testable_keel_data.print_info()
#       3 sampled_testable_keel_data.plot_train_class_distribution()
#       4
#
# ~/Python/PWr-Uczenie-Maszyn/src/preprocessing.py in smote_over_sampling(self, keel_dataset)
#      32     def smote_over_sampling(self, keel_dataset):
#      33         sampler = SMOTE()
# ---> 34         result = self.__base_preprocessing(keel_dataset, sampler)
#      35         return result
#      36
#
# ~/Python/PWr-Uczenie-Maszyn/src/preprocessing.py in __base_preprocessing(self, testable_keel_dataset, sampler)
#      10     def __base_preprocessing(self, testable_keel_dataset: TestableKeelData, sampler):
#      11         dataset = copy.deepcopy(testable_keel_dataset)
# ---> 12         sampled_test_x, sampled_test_y = sampler.fit_resample(dataset.x_test, dataset.y_test)
#      13         sampled_train_x, sampled_train_y = sampler.fit_resample(dataset.x_train, dataset.y_train)
#      14         dataset.update_with_datasets(sampled_train_x, sampled_test_x, sampled_train_y, sampled_test_y)
#
# /usr/local/lib/python3.7/site-packages/imblearn/base.py in fit_resample(self, X, y)
#      79         )
#      80
# ---> 81         output = self._fit_resample(X, y)
#      82
#      83         if self._X_columns is not None or self._y_name is not None:
#
# /usr/local/lib/python3.7/site-packages/imblearn/over_sampling/_smote.py in _fit_resample(self, X, y)
#     725
#     726             self.nn_k_.fit(X_class)
# --> 727             nns = self.nn_k_.kneighbors(X_class, return_distance=False)[:, 1:]
#     728             X_new, y_new = self._make_samples(
#     729                 X_class, y.dtype, class_sample, X_class, nns, n_samples, 1.0
#
# /usr/local/lib/python3.7/site-packages/sklearn/neighbors/_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     615                 "Expected n_neighbors <= n_samples, "
#     616                 " but n_samples = %d, n_neighbors = %d" %
# --> 617                 (n_samples_fit, n_neighbors)
#     618             )
#     619
#
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 3, n_neighbors = 6

# %% [markdown]
# ### Sample data with ADASYN Oversampling

# %%
sampled_testable_keel_data = common_preprocessing.adasyn_over_sampling(random_testable_keel_data)
sampled_testable_keel_data.print_info()
sampled_testable_keel_data.plot_train_class_distribution()
